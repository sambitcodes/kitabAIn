# %% [markdown]
# # Notebook 2: Exploratory Data Analysis (EDA)
#
# **Objective:** Load the cleaned data from `artifacts/` and perform exploratory data analysis to understand the data distributions and find insights.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.offline as py
import plotly.graph_objects as go
import os

py.init_notebook_mode(connected=True)

# Define file paths
ARTIFACTS_DIR = '../artifacts'
BOOKS_PATH = os.path.join(ARTIFACTS_DIR, 'cleaned_books.pkl')
USERS_PATH = os.path.join(ARTIFACTS_DIR, 'cleaned_users.pkl')
RATINGS_PATH = os.path.join(ARTIFACTS_DIR, 'cleaned_ratings.pkl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.2.0.min"</script>

# %%
# Load cleaned data
books_df = pd.read_pickle(BOOKS_PATH)
users_df = pd.read_pickle(USERS_PATH)
ratings_df = pd.read_pickle(RATINGS_PATH)

print("Data loaded successfully!")
# Out:
# Data loaded successfully!

# %% [markdown]
# ## 1. Analysis of Book Ratings

# %%
rating_counts = ratings_df['book_rating'].value_counts().sort_index()
fig = px.bar(rating_counts, 
             x=rating_counts.index, 
             y=rating_counts.values, 
             title='Distribution of Book Ratings',
             labels={'x': 'Rating', 'y': 'Count'},
             color=rating_counts.index,
             template='plotly_dark'
            )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="c7c1c066-e466-4080-83fc-46c1f2514a08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c7c1c066-e466-4080-83fc-46c1f2514a08")) {                    Plotly.newPlot(                        "c7c1c066-e466-4080-83fc-46c1f2514a08",                        [{"hovertemplate":"book_rating=%{marker.color}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i1","bdata":"AAECAwQFBgcICQo="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AAECAwQFBgcICQo="},"xaxis":"x","y":{"dtype":"i4","bdata":"Te0KAOoGAADHCgAAbBcAAMgiAAAexwAAPJAAAKkqAQA4lQEA1QcBABIzAQA="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"m ...

# %% [markdown]
# **Inference:**
# A vast majority of ratings are '0', which represents implicit ratings (user interaction without an explicit score). Among the explicit ratings (1-10), the distribution is skewed towards the higher end, with '8' being the most common rating, followed by '7', '10', and '9'.

# %% [markdown]
# ## 2. Analysis of User Age

# %%
fig = px.histogram(users_df, 
                   x='age', 
                   nbins=50, 
                   title='Distribution of User Ages',
                   template='plotly_dark'
                  )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="d005897b-39e7-4627-9a68-c6a0e054580c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d005897b-39e7-4627-9a68-c6a0e054580c")) {                    Plotly.newPlot(                        "d005897b-39e7-4627-9a68-c6a0e054580c",                        [{"bingroup":"x","hovertemplate":"age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\\...\...\...\...\...\...\...\...\u002fCiA\...\u002fFh0OFR8cJCI\...\...\u002fGSAgICAgFyAgIBwmLiAgIB8\...\\...\...\u002fNA8pICA5IB8gICAgKSAnHh5AICAgJCAYGiAdMBkgICAgIBcWICAlHSAUICsgJiA8ICwtIDYgRykiICcgIB8\...\...\...\...\u002fICBJICAzICggPRwSKDMgIDY2NDogKiAgNSAgKyAjICcWIB4gIDEeKiA2IDMQPRcgICA\...\...\...\...\...\...\u002fIw4gGhwcIB4PFhMgETwgIx0aLEAgEh8ZSSAlHRcjKC0TIBggLy4QICAgMhcgFTIgICAgGCAdGiAyIBEgIBgVERggGxogIyAnICARGCAUIw4gIBkZFhodICUgIBksICwgICAgLiArLDMxGSEgFTMgICAgICAgEg8iQyAcIBocMBQZIBIcICYgGCAiIB4gJyAdLSA3Hx8gIB8dIB8gGyA2ICAbLyApHyA\...\u002fMCAgOiAhIDQVGCkgGSAgMyAgICAaICAgIBAaICMYKCAgNCwgIDEgICUgMhsWOS0gQh4gExIdICAgICMgLiAgLSA\...\...\...\...\...\...\...\...\...\...\...\...\...\\...\...\u002fHisgICAlLiQoWyAgLxIgISAgOSwiGiAgGiAeIBEgIBwgIBAgICASLh0gICAeICAgKh0hOyURMzMgOiAgNSA7MTBDICo4IEknIBYfISAgEBUQFBYgICAkDiUQICAgIDkgFSAcGRRCICAgICAgQCEgFikVIDEbOhogICAkICA5IEEwIDkxTTUgSCAgICAgLiBCICsgNCAgICYTTCAgKCUgIyAgFyAgICAgICAUSxg4IDYzIC4gGy8\u002fGSAbNyBBICUvEjcdICgjIiAgODIWGSQeMRQwICAdFCIqQTkgQiBJIBguGSAzICAqIC4aOR4gICMYGRggIDAgKiAgIC0gNiA\...\...\...\...\...\...\...\...\u002fIEgsIBkgKi0gKCAiIBYgEEszICYxIDsjICQgICAcGyA+WSAgIxkUFhUgGh02KCAVICAfIB0YPD0gESAgICAhIB8gHi44ICA1IEEWPw8kICAWHCAaNiVJHyAgHiAgJRQbICEgICAgJTQrGCAiRiApIhYrKCEfESAiJyARICAgGiAXHxsgJzgiIEgsICAgQUQgICAgICAqNCAgICQgLB4gHRANIDIgLREgIBgiICAgMEEgICAgJSAYDiA\...\...\...\u002fGiogIC0lFyAgHiAgICAxJi0gICANIB8gHyBAFiAgRx8gICAjGxEdICAoIBU\...\...\...\...\...\u002fIBggDzcgIA0gLyA7IBMgKSAUIBwjIBsyICAgIiAgIiIgIBwgJTUeIBsgNCETIBcgIDwgJyc\...\...\...\u002fFSAaQRMbKCAlIBcgICATECcgICAgICAgOyEhIB8gIBoRIBsXOTUgGSArGCYZLSAaKBggICAgJjogICAcIEgQICAaOTU3ICArICAgICg4LCAkICA3HSEwNiogIC8\...\...\\u002fMBcpICAfMCAWNxwfIBcgLDQgOiAgICANICAjRRYgICAmLA81ICA0ICAsMSEgICA2ICAgICUgKhdDIDUrICAXJCANICcfF ...

# %% [markdown]
# **Inference:**
# The distribution of user ages shows a large peak around 25-35. This is the median age we used for imputation, so many of the 'NaN' values were assigned this age. However, even without imputation, the primary user base appears to be in their 20s and 30s.

# %% [markdown]
# ## 3. Analysis of Top Authors

# %%
top_authors = books_df['book_author'].value_counts().head(20)
fig = px.bar(top_authors, 
             x=top_authors.values, 
             y=top_authors.index, 
             orientation='h', 
             title='Top 20 Authors by Number of Books',
             labels={'x': 'Number of Books', 'y': 'Author'},
             template='plotly_dark'
            )
fig.update_yaxes(autorange="reversed")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="6f764320-3264-48c0-9a96-8b0082902011" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f764320-3264-48c0-9a96-8b0082902011")) {                    Plotly.newPlot(                        "6f764320-3264-48c0-9a96-8b0082902011",                        [{"hovertemplate":"Number of Books=%{x}\u003cbr\u003ebook_author=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i2","bdata":"eAI3AgwCpwF1AXQBSgE7ATMBLgEeARoB5wDfANwA2gDZANgA1gDMAA=="},"xaxis":"x","y":["Agatha Christie","William Shakespeare","Stephen King","Ann M. Martin","Carolyn Keene","Francine Pascal","Isaac Asimov","Nora Roberts","Barbara Cartland","Charles Dickens","Not Applicable (Na )","R. L. Stine","Mark Twain","Jane Austen","Terry Pratchett","Mary Higgins Clark","Piers Anthony","Marion Zimmer Bradley","Janet Dailey","Franklin W. Dixon"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}], ...

# %% [markdown]
# **Inference:**
# Agatha Christie, William Shakespeare, and Stephen King are the most prolific authors in this dataset. This indicates a strong presence of classic and popular fiction.

# %% [markdown]
# ## 4. Analysis of Top Publishers

# %%
top_publishers = books_df['publisher'].value_counts().head(20)
fig = px.bar(top_publishers, 
             x=top_publishers.values, 
             y=top_publishers.index, 
             orientation='h', 
             title='Top 20 Publishers by Number of Books',
             labels={'x': 'Number of Books', 'y': 'Publisher'},
             template='plotly_dark'
            )
fig.update_yaxes(autorange="reversed")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="a1412e10-2a2f-458d-b4b2-584f90317af7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a1412e10-2a2f-458d-b4b2-584f90317af7")) {                    Plotly.newPlot(                        "a1412e10-2a2f-458d-b4b2-584f90317af7",                        [{"hovertemplate":"Number of Books=%{x}\u003cbr\u003epublisher=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i2","bdata":"bx18EEEPxw4+DlgMmwscC9MKpwqdCt0J0ggWCP0HoQf3BqgGpAaeBg=="},"xaxis":"x","y":["Harlequin","Silhouette","Pocket","Ballantine Books","Bantam Books","Scholastic","Simon &amp; Schuster","Penguin Books","Berkley Publishing Group","Warner Books","Penguin USA","Harpercollins","Fawcett Books","Signet Book","Random House Inc","St Martins Pr","St. Martin's Press","Tor Books","HarperCollins Publishers","Zebra Books"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line": ...

# %% [markdown]
# **Inference:**
# Mass-market publishers like Harlequin, Silhouette, Pocket, and Ballantine Books dominate the dataset. This suggests a large collection of paperback fiction, particularly romance and mystery.

# %% [markdown]
# ## 5. Analysis of Publication Year

# %%
# Filter out the imputed median year to get a clearer picture, just for this plot
median_year = books_df['year_of_publication'].median()
plot_df = books_df[books_df['year_of_publication'] != median_year]

fig = px.histogram(plot_df, 
                   x='year_of_publication', 
                   nbins=100, 
                   title='Distribution of Publication Years (Imputed values removed for plot)',
                   template='plotly_dark'
                  )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="b79d1ea7-c196-4752-9a7a-3f0e5225be7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b79d1ea7-c196-4752-9a7a-3f0e5225be7a")) {                    Plotly.newPlot(                        "b79d1ea7-c196-4752-9a7a-3f0e5225be7a",                        [{"bingroup":"x","hovertemplate":"year_of_publication=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":100,"orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"0gfRB8cHzwfPB8cH0AfJB9IHxAfQB9QHzwfOB84HzwfKB88HygfPB9EH0wfQB88HzgfUB80H0AfTB84H0gfRB8cH0AfQB8QH0gfJB78HuwfLB9AHygfRB9IH0gfNB88H0AfPB8QHvgfBB8gHyAfJB9IHwgfHB8sH0ge6B7wHygfKB84H0AfNB9MH0we\...\u002fB9MH1AfQB9AHtgfAB80HxAfKB8QHzQfHB8cHsAe4B9IHxQfQB84H0AezB9EH0wfTB9AHzQfFB8cHzgfFB9IHyAfQB84HxgfPB8sHyQfGB8kHxAfDB80H0gfNB9AHzQfCB8oHvgfIB8kHxwe\...\\...\...\...\u002fB8sH0wfFB8YHxgfCB8EH0gfSB9MHwwfNB9MH0we\...\...\u002fB78HvgfEB9MHzQe4B8cHyQfRB8QH0AfRB80HxQfKB9EHwAfSB8AHwwe5B9AHzwfIB8UHxwfIB8YHpQe5B8sHzwfEB8oHzQfPB88H0QfSB80HzgfJB8gHxAfNB8oHyQfEB8gH0gfJB9MHvwe\...\u002fB9MHvgeAB9MHvQfTB84HxgfNB8sHzQfLB8sHyQfLB84HzQfKB80H0QfPB9AHzwfPB9IH0QfQB9IHwgfGB8UH0AfIB9MHxwfPB88H0gfPB80HvgfOB9EH0AfSB8cHtge5B8MHwwfOB8oHzwfGB8UHwwetB7sHyAfRB8oH0QfPB8MHtQfCB88H0AfPB84HzQfRB9EHzwfRB8sHyge\...\...\...\...\...\...\u002fB8gHyQfJB8YHywfIB88H0gfRB8kHtwfPB74HyQfHB8YHyQfLB70HxgfJB70HxQe0B8sH0AfEB74HxAfGB8sHygfBB8YHywfLB9AHzwfSB9IH0gfSB9IHzwfOB8UH0QfKB8gHyQfSB84H0QfRB9IH0gfUB8UHvQfIB9AHzgfUB8sH0AfJB9IHzgfJB7oHxQfHB8IHygfTB9IH0ge8B9AHzwfSB8oHxAfJB9IHywfTB9IHuge\...\...\u002fB8cH0AfOB8kHzQfTB9AH0gfSB8EHygfRB8AHyAfKB9IHxgfFB9AH0QfSB8sHywfJB9MH0wfNB84H0gfQB8UHxAe+B8EHxgfGB8oHywfNB8sHxwetB70HvgfFB8oHyAfNB8kH0gfNB8sHygfRB9EH0ge8B80HywfQB7sH0gfGB9IHzgfPB9EH0AfTB9EH0AfRB8kHwwfQB9MH0wfTB8sHvQfJB8sHyQe\...\\u002fB9IHzQfNB9IH0gfGB8cHxwfJB88HyAfRB80HyQfLB88HzQfLB8QHzwfCB8MHygfOB84H0QfKB9QHywfLB88H0ge\...\u002fB9MH0wfNB7sHywfQB8YHyQe+B80H0gfRB8cHyQfSB8oH0QfQB8kHzgfNB84H0QfHB8kHyQfLB8YHzQfEB8YH0AfPB9AH0AfQB80H0AfPB9EHzgfQB84H0gfPB80H0AfOB9AH0QfSB9EHywfLB8cHxwfRB84H0Ae+B8YHxwfSB9IH0gfSB9IHxge+B8AHwwfGB84HtwfOB8YHyAfKB88HyAfIB8cH0QfRB9AH0AfQB84Hzge\u002fB80H0wfSB9MH0wfRB9AH0AfKB8cHyQfTB8oH0wfKB8gH0QfTB80HzwfOB84HyAfNB9AHzgfOB9EHzwfRB9AH0we+B8YHzQfLB8sH0QfIB8cHwQfNB8YHvwfHB8cHywfRB9MH0wfRB9MH0gfTB9EH0wfSB9MH0gfPB9IHywfQB9MH0wfQB8gHzwe\u002fB8UHzgfPB78H0AfUB9MH0wfTB8IHxgfNB7gHyQfQB8AHyQfPB7wH0QfPB8oHxAfNB8MHzgfAB8kHywfPB7oHvgfOB78HyAe\\u002fB74HywfHB80HzQfOB9AHyAfHB84HxwfIB8YHxQfGB80HyAfKB8oHxwfKB8UHzwfQB9QHyAfIB8EHwwe\u002fB84HygfIB8gHyAfRB9MH0AfQB9QH1AfUB9IH0gfFB9IH0gf ...

# %% [markdown]
# **Inference:**
# After removing the imputed median value (which would create a massive spike), we see a clear trend: the number of books published increases significantly from the 1950s onwards, peaking in the late 1990s and early 2000s. This aligns with the dataset's collection period.

# %% [markdown]
# ## 6. Analysis of User Location (Top Countries)

# %%
top_countries = users_df['country'].value_counts().head(20)
fig = px.bar(top_countries, 
             x=top_countries.values, 
             y=top_countries.index, 
             orientation='h', 
             title='Top 20 User Countries',
             labels={'x': 'Number of Users', 'y': 'Country'},
             template='plotly_dark'
            )
fig.update_yaxes(autorange="reversed")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="7dbd402e-ca87-41f1-a516-6fbca4e57977" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7dbd402e-ca87-41f1-a516-6fbca4e57977")) {                    Plotly.newPlot(                        "7dbd402e-ca87-41f1-a516-6fbca4e57977",                        [{"hovertemplate":"Number of Users=%{x}\u003cbr\u003ecountry=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i4","bdata":"vyECAJpUAABqSAAAk0IAAFszAAAILgAAAiwAAOIRAAB\u002fDQAA\u002fQwAABkMAADRCwAA0QYAAIoGAADQBQAAfgUAAAoFAABwBAAAXwQAADsEAAA="},"xaxis":"x","y":["usa","canada","united kingdom","germany","spain","australia","italy","","france","portugal","new zealand","netherlands","switzerland","brazil","china","sweden","india","austria","malaysia","argentina"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"out ...

# %% [markdown]
# **Inference:**
# The dataset is overwhelmingly dominated by users from the 'usa', followed by 'canada', 'united kingdom', 'germany', and 'spain'. The 'unknown' category is also large, stemming from missing location data.
